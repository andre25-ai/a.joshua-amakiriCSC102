# %%
import tkinter as tk
from tkinter import messagebox

# STEP 1: THE FULL DATABASE (All 40 Employees from GIG-logistics.pdf)
employees = [
    {"id": "GIG001", "name": "Chukwuemeka Okafor", "dept": "Operations"},
    {"id": "GIG002", "name": "Adaeze Nwosu", "dept": "Operations"},
    {"id": "GIG003", "name": "Tunde Adeleke", "dept": "Operations"},
    {"id": "GIG004", "name": "Ngozi Eze", "dept": "Operations"},
    {"id": "GIG005", "name": "Emeka Chu", "dept": "Operations"},
    {"id": "GIG006", "name": "Fatima Bello", "dept": "Operations"},
    {"id": "GIG007", "name": "Seun Adesanya", "dept": "Operations"},
    {"id": "GIG008", "name": "Kelechi On", "dept": "Operations"},
    {"id": "GIG009", "name": "Hauwa Musa", "dept": "Finance"},
    {"id": "GIG010", "name": "Rotimi Ade", "dept": "Finance"},
    {"id": "GIG011", "name": "Chioma Obi", "dept": "Finance"},
    {"id": "GIG012", "name": "Yusuf Garba", "dept": "Finance"},
    {"id": "GIG013", "name": "Blessing Ok", "dept": "Finance"},
    {"id": "GIG014", "name": "Taiwo Akin", "dept": "Finance"},
    {"id": "GIG015", "name": "Amina Usman", "dept": "Human Res"},
    {"id": "GIG016", "name": "Ifeanyi Okc", "dept": "Human Res"},
    {"id": "GIG017", "name": "Sade Fasho", "dept": "Human Res"},
    {"id": "GIG018", "name": "Nnamdi Ok", "dept": "Human Res"},
    {"id": "GIG019", "name": "Maryam Al", "dept": "Human Res"},
    {"id": "GIG020", "name": "Oluwaseun Balogun", "dept": "Technology"},
    {"id": "GIG021", "name": "Chidi Nwachukwu", "dept": "Technology"},
    {"id": "GIG022", "name": "Aisha Lawal", "dept": "Technology"},
    {"id": "GIG023", "name": "Gbenga Adebisi", "dept": "Technology"},
    {"id": "GIG024", "name": "Nneka Oduya", "dept": "Technology"},
    {"id": "GIG025", "name": "Ibrahim Suleiman", "dept": "Technology"},
    {"id": "GIG026", "name": "Tolulope Ogunwale", "dept": "Customer"},
    {"id": "GIG027", "name": "Esther Aniemeka", "dept": "Customer S"},
    {"id": "GIG028", "name": "Biodun Ojo", "dept": "Customer S"},
    {"id": "GIG029", "name": "Rukayat Folarin", "dept": "Customer"},
    {"id": "GIG030", "name": "Chinedu Obiora", "dept": "Customer S"},
    {"id": "GIG031", "name": "Damilola Akintola", "dept": "Sales"},
    {"id": "GIG032", "name": "Uche Okereke", "dept": "Sales"},
    {"id": "GIG033", "name": "Zainab Idris", "dept": "Sales"},
    {"id": "GIG034", "name": "Femi Adeyinka", "dept": "Sales"},
    {"id": "GIG035", "name": "Precious Igwe", "dept": "Sales"},
    {"id": "GIG036", "name": "Lara Oduola", "dept": "Marketing"},
    {"id": "GIG037", "name": "Tochukwu Eze", "dept": "Marketing"},
    {"id": "GIG038", "name": "Hadiza Yakubu", "dept": "Marketing"},
    {"id": "GIG039", "name": "Victor Osemeka", "dept": "Marketing"},
    {"id": "GIG040", "name": "Chidinma Nwofor", "dept": "Marketing"}
]

def verify_employee():
    # Get user input
    user_name = name_entry.get().strip()
    user_dept = dept_entry.get().strip()

    # Search for a match in our data
    match = None
    for emp in employees:
        if emp["name"].lower() == user_name.lower() and emp["dept"].lower() == user_dept.lower():
            match = emp
            break

    if match:
        # Success Window
        success_win = tk.Toplevel(root)
        success_win.title("Access Granted")
        success_win.geometry("400x450")
        
        tk.Label(success_win, text=f"Welcome, {match['name']}!", font=("Arial", 12, "bold"), fg="darkgreen").pack(pady=10)
        tk.Label(success_win, text=f"Department: {match['dept']}").pack()
        tk.Label(success_win, text="\nOther members in your department:", font=("Arial", 10, "italic")).pack()

        # Display other members of the same department
        for emp in employees:
            if emp["dept"].lower() == user_dept.lower() and emp["name"] != match["name"]:
                tk.Label(success_win, text=f"• {emp['name']} ({emp['id']})").pack(anchor="w", padx=60)
    else:
        # Error Pop-up
        messagebox.showerror("Verification Failed", "Employee does not exist or department is incorrect.")

# STEP 2: MAIN WINDOW UI
root = tk.Tk()
root.title("GIG Logistics - Employee Portal")
root.geometry("400x300")

tk.Label(root, text="EMPLOYEE VERIFICATION", font=("Arial", 14, "bold")).pack(pady=20)

tk.Label(root, text="Full Name:").pack()
name_entry = tk.Entry(root, width=35)
name_entry.pack(pady=5)

tk.Label(root, text="Department:").pack()
dept_entry = tk.Entry(root, width=35)
dept_entry.pack(pady=5)

verify_btn = tk.Button(root, text="VERIFY IDENTITY", command=verify_employee, bg="navy", fg="white", font=("Arial", 10, "bold"))
verify_btn.pack(pady=25)

root.mainloop()
