# %% [markdown]
# import numpy as np
#
# print("Program to find the roots of three types of equations")
# print("1. Quadratic")
# print("2. Cubic")
# print("3. Quartic")
#
# choice = int(input("Pick an option between (!-3)"))
#
# if choice == 1:
#     a = float(input("Enter a: "))
#     b = float(input("Enter b: "))
#     c = float(input("Enter c: "))
#
#     roots = np.roots([a,b,c])
#     print("Roots are: ",roots)
#
# elif choice == 2:
#     a = float(input("Enter a: "))
#     b = float(input("Enter b: "))
#     c = float(input("Enter c: "))
#     d = float(input("Enter d: "))
#
#     roots = np.roots([a,b,c,d])
#     print("Roots are: ",roots)
#
# elif choice == 3:
#     a = float(input("Enter a: "))
#     b = float(input("Enter b: "))
#     c = float(input("Enter c: "))
#     d = float(input("Enter d: "))
#     e = float(input("Enter e: "))
#
#     roots = np.roots([a,b,c,d,e])
#     print("Roots are: ",roots)
#
# else:
#     print("Invalid choice")

# %% [markdown]
# ALGORITHM
# Start
# 1. Start the program
#
# 2. Import the NumPy library
#
#
# 3. Display menu options to the user
#    a -  Quadratic Equation
#    b -  Cubic Equation
#    c -  Quartic Equation
#
# 4. Ask the user to choose an option
#
# 5. Check the user's choice.
#
# 6. (If choice = 1 : Quadratic)
# Ask the user to enter coefficient a
# Ask the user to enter coefficient b
# Ask the user to enter coefficient c
# Store the coefficients in a list [a, b, c]
# Use NumPy roots function to compute the roots
# Display the roots
#
# 7. (If choice = 2 : Cubic)
# Ask the user to enter coefficient a
# Ask the user to enter coefficient b
# Ask the user to enter coefficient c
# Ask the user to enter coefficient d
# Store the coefficients in a list [a, b, c, d]
# Use NumPy roots function to compute the roots
# Display the roots
#
# 8. (If choice = 3 : Quartic)
# Ask the user to enter coefficient a
# Ask the user to enter coefficient b
# Ask the user to enter coefficient c
# Ask the user to enter coefficient d
# Ask the user to enter coefficient e
# Store the coefficients in a list [a, b, c, d, e]
# Use NumPy roots function to compute the roots
# Display the roots
#
# 9. (If the choice is not 1, 2, or 3)
# Display Invalid choice
#
# 10. End program
